# %% [markdown]
# ## Question 1

# %% [markdown]
# Flask is a lightweight backend framework with minimal dependencies that is easy to learn because its simple and intuitive API makes it easy to learn and use for beginners. Flask is a flexible Framework because it allows you to customize and extend the framework to suit your needs easily. Flask is highly scalable for simple applications and easy to build a quick prototype. Routing URL is easy and Flask is easy to develop and maintain applications. Flask has higher compatibility with latest technologies. Flask’s codebase size is relatively smaller and has good documentation

# %% [markdown]
# ## Quesetion 2

# %%
from flask import Flask
from flask import request

# %%
pip install flask
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
app = Flask(__name__)

@app.route("/h")
def hello_world1():
  return "<h1>Hello world!</h1>"
if __name__=="__main__":
  app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.18.0.12:5000
# Press CTRL+C to quit

# %% [markdown]
# ![screenshot1.png](attachment:01f549e2-cf54-44d2-bfc8-3bd4f4d6d582.png)

# %% [markdown]
# ## Question 3

# %% [markdown]
# App routing is used to map the specific URL with the associated function that is intended to perform some task. The routing technique helps a user remember application URLs and is useful to access the desired page directly without having to navigate from the home page. The route () decorator in Flask is used to bind URL to a function. We use app routes because it helps us to create a URL for our web application. It also helps us to create a URL for each page of our web application.

# %% [markdown]
# ## Question 4

# %%
@app.route("/welcome")
def welcome():
  return "<h1>Welcome to ABC cooperation</h1>"

@app.route("/")
def show_details():
    return "Company : ABC Cooporation \n Country : INDIA \n contact details : 999-999-9999"
if __name__=="__main__":
  app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.18.0.12:5000
# Press CTRL+C to quit

# %% [markdown]
# dsfs![screenshot2.png](attachment:f8df45bd-b5c1-4526-89fd-cf60392816e7.png)

# %% [markdown]
# ![screenshot3.png](attachment:65d4b048-7164-404f-a796-a72aae170c09.png)

# %% [markdown]
# ## Question 5

# %% [markdown]
# To build URLs in Flask, we use the url_for() function. The name of the function is accepted as its first argument and any number of keyword arguments. The unknown variable parts in a website are then appended to the URL as query parameters.

# %%
from flask import Flask, url_for

# %%
@app.route("/index")
def index():
    return 'index'

@app.route("/login")
def login():
    return "login"

@app.route("/user/<username>")
def profile(username):
    return f"{username}\'s profile"

with app.test_request_context():
    print(url_for("index"))
    print(url_for("login"))
    print(url_for("login",next="/"))
    print(url_for("profile",username = 'gaurav'))
# Out:
# /index
# /login
# /login?next=/
# /user/gaurav
